# %% [markdown]
# # ***Assignment***

# %% [markdown]
# ### **OOPS**

# %% [markdown]
# **1. What is Object-Oriented Programming (OOP)?**

# %% [markdown]
# It is a way of programming that orgainizes the code into objects that combines attributes and methods together.

# %% [markdown]
# **2. What is a class in OOP?**

# %% [markdown]
# It is a blue print used to create Objects.

# %% [markdown]
# **3. What is an object in OOP?**

# %% [markdown]
# It is an instance of the class, which represents a real-world entity and contains actual data defined by the class.

# %% [markdown]
# **4. What is the difference between abstraction and encapsulation?**

# %% [markdown]
# Abstraction hides implementation details and shows only the essential features
# and Encapsulation restrict direct access to data.

# %% [markdown]
# **5. What are dunder methods in Python?**

# %% [markdown]
# Special methods in python that begins and ends with double underscore like __init__.

# %% [markdown]
# **6. Explain the concept of inheritance in OOP.**

# %% [markdown]
# It allows a class to get the properties of another class, used when we need the properties of another predefined class in a new class with some additional properties, this reduces the manual work of rewriting the same lines.

# %% [markdown]
# **7. What is polymorphism in OOP?**

# %% [markdown]
# It allows same method name to behave differently on a abject its applied in.

# %% [markdown]
# **8. How is encapsulation achieved in Python?**

# %% [markdown]
# By starting the name of the variable with _ or __.

# %% [markdown]
# **9. What is a constructor in Python?**

# %% [markdown]
# A special methos __init__ which is automatically called when an object is created.

# %% [markdown]
# **10. What are class and static methods in Python?**

# %% [markdown]
# Class methods operate on the class itself and use cls.
# Static methods do not use class or instance data and behave like regular functions inside a class.

# %% [markdown]
# **11. What is method overloading in Python?**

# %% [markdown]
# It means defining multiple parameters using same name but different parameters.

# %% [markdown]
# **12. What is method overriding in OOP?**

# %% [markdown]
# Method overriding occurs when a subclass provides a specific implementation of a method already defined in its parent class.

# %% [markdown]
# ### Practical Questions

# %% [markdown]
# **1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".**

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")
class Dog(Animal):
    def speak(self):
        print("Bark")
d = Dog()
d.speak()
# Out:
# Bark

# %% [markdown]
# **2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.**

# %%
import math
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi * self.radius ** 2
class Rectangle(Shape):
    def __init__(self, l, b):
        self.l = l
        self.b = b
    def area(self):
        return self.l * self.b
x = Circle(5)
print(f'Area of circle = {x.area()}')
y = Rectangle(3,5)
print(f'Area of rectangle = {y.area()}')
# Out:
# Area of circle = 78.53981633974483
# Area of rectangle = 15

# %% [markdown]
# **3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.**

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type
class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand
class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery
X = ElectricCar('unknown', 'Tesla', '1KAh')
print(f'The car is electric and is made by {X.brand}, also has a battery of {X.battery} making it suitable for long journey')
# Out:
# The car is electric and is made by Tesla, also has a battery of 1KAh making it suitable for long journey

# %% [markdown]
# **4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.**

# %%
class Bird:
    def fly(self):
        print("Bird can fly")
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies")
class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

# %% [markdown]
# **5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.**

# %%
class BankAccount:
    def __init__(self, name, balance):
        self.name = name
        self.__balance = balance
    def deposit(self, amount):
        self.__balance += amount
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")
    def check_balance(self):
        return self.__balance
my_acc = BankAccount('Krish', 20)
my_acc.withdraw(3_00_00_000)
my_acc.check_balance()
# Out:
# Insufficient balance
# 20

# %% [markdown]
# **6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().**

# %%
class Instrument:
    def play(self):
        print("Instrument plays sound")
class Guitar(Instrument):
    def play(self):
        return "Guitar produces sound by the vibration of string"
class Piano(Instrument):
    def play(self):
        return "Piano produces sound in a rythm"
x = Piano()
y = Guitar()
print(f'The physics teacher brought guitar in the class to explain how {y.play()}')
print(f'Piano is easy to learn because {x.play()}')
# Out:
# The physics teacher brought guitar in the class to explain how Guitar produces sound by the vibration of string
# Piano is easy to learn because Piano produces sound in a rythm

# %% [markdown]
# **7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.**

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %% [markdown]
# **8. Implement a class Person with a class method to count the total number of persons created.**

# %%
class Person:
    count = 0
    def __init__(self):
        Person.count += 1
    @classmethod
    def total_persons(cls):
        return cls.count

# %% [markdown]
# **9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".**

# %%
class Fraction:
    def __init__(self, n, d):
        self.numerator = n
        self.denominator = d
    def __str__(self):
        return self.numerator/self.denominator

# %% [markdown]
# **10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.**

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)
    def __str__(self):
        return f"({self.x}, {self.y})"

# %% [markdown]
# **11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."**

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %% [markdown]
# **12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.**

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades
    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# %% [markdown]
# **13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.**

# %%
class Rectangle:
    def set_dimensions(self, l, b):
        self.l = l
        self.b = b
    def area(self):
        return self.l * self.b

# %% [markdown]
# **14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary**

# %%
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate
class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return super().calculate_salary(hours, rate) + bonus

# %% [markdown]
# **15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.**

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    def total_price(self):
        return self.price * self.quantity
Drone = Product('Quadcopter', 35_000, 2)
Drone.total_price()
# Out:
# 70000

# %% [markdown]
# **16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.**

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
class Cow(Animal):
    def sound(self):
        print("Moo")
class Sheep(Animal):
    def sound(self):
        print("Baa")

# %% [markdown]
# **17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.**

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published
    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Published at: {self.year_published}"

# %% [markdown]
# **18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.**

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
